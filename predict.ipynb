# %%
import pickle
import numpy as np

# %%
with open("model/house_price_model.pkl", "rb") as f:
    model = pickle.load(f)

# %%
new_house = np.array([[10000, 5, 2005, 1000, 1900, 3]])

# %%
predicted_price = model.predict(new_house)

print("Predicted House Price:", predicted_price[0])
# Out:
# Predicted House Price: 191537.80130703642
# c:\Users\lenovo\anaconda3\envs\HousePricePrediction\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
